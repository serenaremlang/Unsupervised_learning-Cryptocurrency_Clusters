# %%
# Initial imports
import pandas as pd
from pathlib import Path

# %% [markdown]
# # Data Preparation

# %% [markdown]
# Load the data into a Pandas DataFrame

# %%
# Data loading
file_path = Path("Resources/crypto_data.csv")
df = pd.read_csv(file_path)
df
# Out:
#      Unnamed: 0        CoinName Algorithm  IsTrading ProofType  \
# 0            42         42 Coin    Scrypt       True   PoW/PoS
# 1           365         365Coin       X11       True   PoW/PoS
# 2           404         404Coin    Scrypt       True   PoW/PoS
# 3           611       SixEleven   SHA-256       True       PoW
# 4           808             808   SHA-256       True   PoW/PoS
# ...         ...             ...       ...        ...       ...
# 1247        XBC     BitcoinPlus    Scrypt       True       PoS
# 1248       DVTC      DivotyCoin    Scrypt      False   PoW/PoS
# 1249       GIOT     Giotto Coin    Scrypt      False   PoW/PoS
# 1250       OPSC  OpenSourceCoin   SHA-256      False   PoW/PoS
# 1251       PUNK       SteamPunk       PoS      False       PoS
#
#       TotalCoinsMined TotalCoinSupply
# 0        4.199995e+01              42
# 1                 NaN      2300000000
# 2        1.055185e+09       532000000
# 3                 NaN          611000
# ...

# %% [markdown]
# Discard all cryptocurrencies that are not being traded. In other words, filter for currencies that are currently being traded. Once you have done this, drop the `IsTrading` column from the dataframe.

# %%
# Filter based on currencies that are currently being traded
df_traded = df[df['IsTrading']==True]
df_traded
# Out:
#      Unnamed: 0     CoinName    Algorithm  IsTrading ProofType  \
# 0            42      42 Coin       Scrypt       True   PoW/PoS
# 1           365      365Coin          X11       True   PoW/PoS
# 2           404      404Coin       Scrypt       True   PoW/PoS
# 3           611    SixEleven      SHA-256       True       PoW
# 4           808          808      SHA-256       True   PoW/PoS
# ...         ...          ...          ...        ...       ...
# 1243       SERO   Super Zero       Ethash       True       PoW
# 1244        UOS          UOS      SHA-256       True      DPoI
# 1245        BDX       Beldex  CryptoNight       True       PoW
# 1246        ZEN      Horizen     Equihash       True       PoW
# 1247        XBC  BitcoinPlus       Scrypt       True       PoS
#
#       TotalCoinsMined TotalCoinSupply
# 0        4.199995e+01              42
# 1                 NaN      2300000000
# 2        1.055185e+09       532000000
# 3                 NaN          611000
# ...

# %%
# Drop 'IsTrading' column
df_cleaned = df_traded.drop(['IsTrading'], axis='columns')
df_cleaned
# Out:
#      Unnamed: 0     CoinName    Algorithm ProofType  TotalCoinsMined  \
# 0            42      42 Coin       Scrypt   PoW/PoS     4.199995e+01
# 1           365      365Coin          X11   PoW/PoS              NaN
# 2           404      404Coin       Scrypt   PoW/PoS     1.055185e+09
# 3           611    SixEleven      SHA-256       PoW              NaN
# 4           808          808      SHA-256   PoW/PoS     0.000000e+00
# ...         ...          ...          ...       ...              ...
# 1243       SERO   Super Zero       Ethash       PoW              NaN
# 1244        UOS          UOS      SHA-256      DPoI              NaN
# 1245        BDX       Beldex  CryptoNight       PoW     9.802226e+08
# 1246        ZEN      Horizen     Equihash       PoW     7.296538e+06
# 1247        XBC  BitcoinPlus       Scrypt       PoS     1.283270e+05
#
#      TotalCoinSupply
# 0                 42
# 1         2300000000
# 2          532000000
# 3             611000
# 4                  0
# ...

# %% [markdown]
# Remove all rows that have at least one null value.

# %%
# Drop nulls
df_nonull = df_cleaned.dropna()
df_nonull
# Out:
#      Unnamed: 0     CoinName    Algorithm ProofType  TotalCoinsMined  \
# 0            42      42 Coin       Scrypt   PoW/PoS     4.199995e+01
# 2           404      404Coin       Scrypt   PoW/PoS     1.055185e+09
# 4           808          808      SHA-256   PoW/PoS     0.000000e+00
# 5          1337    EliteCoin          X13   PoW/PoS     2.927942e+10
# 7           BTC      Bitcoin      SHA-256       PoW     1.792718e+07
# ...         ...          ...          ...       ...              ...
# 1238       ZEPH       ZEPHYR      SHA-256      DPoS     2.000000e+09
# 1242        GAP      Gapcoin       Scrypt   PoW/PoS     1.493105e+07
# 1245        BDX       Beldex  CryptoNight       PoW     9.802226e+08
# 1246        ZEN      Horizen     Equihash       PoW     7.296538e+06
# 1247        XBC  BitcoinPlus       Scrypt       PoS     1.283270e+05
#
#      TotalCoinSupply
# 0                 42
# 2          532000000
# 4                  0
# 5       314159265359
# 7           21000000
# ...

# %% [markdown]
# Filter for cryptocurrencies that have been mined. That is, the total coins mined should be greater than zero.

# %%
# Filter for Total Coins Mined greater than 0
df_mined = df_nonull[df_nonull['TotalCoinsMined']>0]
df_mined
# Out:
#      Unnamed: 0     CoinName    Algorithm ProofType  TotalCoinsMined  \
# 0            42      42 Coin       Scrypt   PoW/PoS     4.199995e+01
# 2           404      404Coin       Scrypt   PoW/PoS     1.055185e+09
# 5          1337    EliteCoin          X13   PoW/PoS     2.927942e+10
# 7           BTC      Bitcoin      SHA-256       PoW     1.792718e+07
# 8           ETH     Ethereum       Ethash       PoW     1.076842e+08
# ...         ...          ...          ...       ...              ...
# 1238       ZEPH       ZEPHYR      SHA-256      DPoS     2.000000e+09
# 1242        GAP      Gapcoin       Scrypt   PoW/PoS     1.493105e+07
# 1245        BDX       Beldex  CryptoNight       PoW     9.802226e+08
# 1246        ZEN      Horizen     Equihash       PoW     7.296538e+06
# 1247        XBC  BitcoinPlus       Scrypt       PoS     1.283270e+05
#
#      TotalCoinSupply
# 0                 42
# 2          532000000
# 5       314159265359
# 7           21000000
# 8                  0
# ...

# %% [markdown]
# In order for your dataset to be comprehensible to a machine learning algorithm, its data should be numeric. Since the coin names do not contribute to the analysis of the data, delete the `CoinName` from the original dataframe.

# %%
# Drop 'CoinName' column
df_reduced = df_mined.drop(['CoinName', "Unnamed: 0"], axis='columns')
df_reduced
# Out:
#         Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 0          Scrypt   PoW/PoS     4.199995e+01              42
# 2          Scrypt   PoW/PoS     1.055185e+09       532000000
# 5             X13   PoW/PoS     2.927942e+10    314159265359
# 7         SHA-256       PoW     1.792718e+07        21000000
# 8          Ethash       PoW     1.076842e+08               0
# ...           ...       ...              ...             ...
# 1238      SHA-256      DPoS     2.000000e+09      2000000000
# 1242       Scrypt   PoW/PoS     1.493105e+07       250000000
# 1245  CryptoNight       PoW     9.802226e+08      1400222610
# 1246     Equihash       PoW     7.296538e+06        21000000
# 1247       Scrypt       PoS     1.283270e+05         1000000
#
# [532 rows x 4 columns]

# %% [markdown]
# Convert the remaining features with text values, Algorithm and ProofType, into numerical data.

# %%
# Get shape of dataset
df_reduced.shape
# Out:
# (532, 4)

# %%
# Use one-hot encoding to create dummy variables for categorical features
df_numeric = pd.get_dummies(df_reduced)
# See shape of new dataset
df_numeric.shape
# Out:
# (532, 377)

# %%
df_numeric
# Out:
#       TotalCoinsMined  Algorithm_1GB AES Pattern Search  Algorithm_536  \
# 0        4.199995e+01                                 0              0
# 2        1.055185e+09                                 0              0
# 5        2.927942e+10                                 0              0
# 7        1.792718e+07                                 0              0
# 8        1.076842e+08                                 0              0
# ...               ...                               ...            ...
# 1238     2.000000e+09                                 0              0
# 1242     1.493105e+07                                 0              0
# 1245     9.802226e+08                                 0              0
# 1246     7.296538e+06                                 0              0
# 1247     1.283270e+05                                 0              0
#
#       Algorithm_Argon2d  Algorithm_BLAKE256  Algorithm_Blake  \
# ...

# %% [markdown]
# While the number of rows remained the same, the number of columns increased from 4 to 377

# %% [markdown]
# Standardize your dataset so that columns that contain larger values do not unduly influence the outcome.

# %%
# Scale the data
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_data = scaler.fit_transform(df_numeric)

# %%
# List of columns from the original DataFrame
column_names = df_numeric.columns
# Assign scaled data to DataFrame
df_scaled = pd.DataFrame(scaled_data, columns=column_names)

# %%
df_scaled
# Out:
#      TotalCoinsMined  Algorithm_1GB AES Pattern Search  Algorithm_536  \
# 0          -0.117108                         -0.043396      -0.043396
# 1          -0.093970                         -0.043396      -0.043396
# 2           0.524946                         -0.043396      -0.043396
# 3          -0.116715                         -0.043396      -0.043396
# 4          -0.114747                         -0.043396      -0.043396
# ..               ...                               ...            ...
# 527        -0.073251                         -0.043396      -0.043396
# 528        -0.116781                         -0.043396      -0.043396
# 529        -0.095613                         -0.043396      -0.043396
# 530        -0.116948                         -0.043396      -0.043396
# 531        -0.117105                         -0.043396      -0.043396
#
#      Algorithm_Argon2d  Algorithm_BLAKE256  Algorithm_Blake  \
# 0            -0.043396            -0.06143        -0.075307
# ...

# %% [markdown]
# # Dimensionality Reduction

# %%
from sklearn.decomposition import PCA
# Initialize PCA model
pca = PCA(n_components=0.90)

# Get principal components
crypto_pca = pca.fit_transform(df_scaled)

# %%
df_crypto_pca = pd.DataFrame(data=crypto_pca)
df_crypto_pca.shape
# Out:
# (532, 274)

# %% [markdown]
# Using PCA with explained variance set to 90% we were able to reduce the number of features from 377 to 274.

# %% [markdown]
# Next, we will further reduce the dataset dimensions with t_SNE and visually inspect the results.

# %%
from sklearn.manifold import TSNE
# Initialize t-SNE model
tsne = TSNE(learning_rate=50)

# %%
# Reduce dimensions
tsne_features = tsne.fit_transform(df_crypto_pca)
tsne_features.shape
# Out:
# (532, 2)

# %%
# Prepare to plot the dataset

# The first column of transformed features
df_crypto_pca['x'] = tsne_features[:,0]

# The second column of transformed features
df_crypto_pca['y'] = tsne_features[:,1]

# %%
import matplotlib.pyplot as plt
# Visualize the clusters
plt.scatter(df_crypto_pca['x'], df_crypto_pca['y'])
plt.show()

# %% [markdown]
# There appears to be one large cluster with some surrounding outliers

# %% [markdown]
# # Cluster Analysis with k-Means

# %%
from sklearn.cluster import KMeans
inertia = []
k = list(range(1, 11))

# Calculate the inertia for the range of k values
for i in k:
    km = KMeans(n_clusters=i, random_state=0)
    km.fit(df_crypto_pca)
    inertia.append(km.inertia_)

# Create the Elbow Curve using hvPlot
elbow_data = {"k": k, "inertia": inertia}
df_elbow = pd.DataFrame(elbow_data)
df_elbow.head()
# Out:
#    k        inertia
# 0  1  345566.760264
# 1  2  300375.703468
# 2  3  269429.803959
# 3  4  254155.661363
# 4  5  242633.130012

# %%
# Plot the elbow curve to find the best candidate(s) for k
plt.plot(df_elbow['k'], df_elbow['inertia'])
plt.xticks(range(1,11))
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.title('Elbow curve for cryptocurrency data')
plt.show()

# %% [markdown]
# Although certainly not the clearest elbow plot, one could argue that the elbow is located at a k = 3.

# %% [markdown]
# # Recommendation
#
# Can cryptocurrencies be clustered together? I would argue yes, but I would do so with caution. Based on the t-SNE plot, we see a single cluster with three more concentrated clusters within it. Additionally, based on our k-means clustering analysis and our elbow plot, this further supports the presense of 3 clusters but again, not highly distinct clusters. If we are looking to make relatively small/low risk investments, the clusters could serve as another variable to help characterize a cryptocurrency based on these three cluster's characteristics. However, I would not make strong assumptions based on these groupings as there are a large number of outliers that are not represented in any cluster for in this model.
